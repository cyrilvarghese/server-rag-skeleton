# %%
! pip install -U langchain openai chromadb langchain-experimental # (newest versions required for multi-modal)
# Out:
# Requirement already satisfied: langchain in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (0.1.12)
# Collecting langchain
#   Downloading langchain-0.1.16-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: openai in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (1.14.2)
# Collecting openai
#   Downloading openai-1.17.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: chromadb in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (0.4.24)
# Requirement already satisfied: langchain-experimental in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (0.0.54)
# Collecting langchain-experimental
#   Downloading langchain_experimental-0.0.57-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from langchain) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from langchain) (3.9.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from langchain) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from langchain) (1.33)
# Collecting langchain-community<0.1,>=0.0.32 (from langchain)
#   Downloading langchain_community-0.0.32-py3-none-any.whl.metadata (8.5 kB)
# Collecting langchain-core<0.2.0,>=0.1.42 (from langchain)
#   Downloading langchain_core-0.1.42-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from langchain) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from langchain) (0.1.22)
# Requirement already satisfied: numpy<2,>=1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from langchain) (2.6.3)
# Requirement already satisfied: requests<3,>=2 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from openai) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from openai) (0.24.1)
# Requirement already satisfied: sniffio in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from openai) (4.10.0)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (0.109.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.27.1)
# Requirement already satisfied: posthog>=2.4.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (3.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (1.15.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (1.23.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (1.23.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (0.44b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (1.23.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (0.15.2)
# Requirement already satisfied: pypika>=0.48.9 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (6.1.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (1.62.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (4.0.1)
# Requirement already satisfied: typer>=0.9.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (29.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (3.9.15)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: idna>=2.8 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from fastapi>=0.95.2->chromadb) (0.36.3)
# Requirement already satisfied: certifi in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2023.11.17)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (0.17.3)
# Requirement already satisfied: jsonpointer>=1.9 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: six>=1.9.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.28.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.26.18)
# Requirement already satisfied: packaging<24.0,>=23.2 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from langchain-core<0.2.0,>=0.1.42->langchain) (23.2)
# Requirement already satisfied: coloredlogs in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: protobuf in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (4.24.4)
# Requirement already satisfied: sympy in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<7.0,>=6.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (6.10.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.62.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.23.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.23.0)
# Requirement already satisfied: opentelemetry-proto==1.23.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.23.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.44b0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.44b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.44b0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.44b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.44b0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.44b0)
# Requirement already satisfied: opentelemetry-util-http==0.44b0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.44b0)
# Requirement already satisfied: setuptools>=16.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (68.2.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-instrumentation-asgi==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.7.2)
# Requirement already satisfied: monotonic>=1.5 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (1.5)
# Requirement already satisfied: backoff>=1.10.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from tokenizers>=0.13.2->chromadb) (0.20.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (10.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.2.0)
# Requirement already satisfied: zipp>=0.5 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from importlib-metadata<7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.5.1)
# Downloading langchain-0.1.16-py3-none-any.whl (817 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.7/817.7 kB 4.5 MB/s eta 0:00:0000:0100:01
# Downloading openai-1.17.1-py3-none-any.whl (268 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.3/268.3 kB 6.6 MB/s eta 0:00:00:00:01
# Downloading langchain_experimental-0.0.57-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.4/193.4 kB 6.4 MB/s eta 0:00:00
# Downloading langchain_community-0.0.32-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 8.1 MB/s eta 0:00:0000:0100:01m
# Downloading langchain_core-0.1.42-py3-none-any.whl (287 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.5/287.5 kB 7.9 MB/s eta 0:00:00:00:01
# Installing collected packages: openai, langchain-core, langchain-community, langchain, langchain-experimental
#   Attempting uninstall: openai
#     Found existing installation: openai 1.14.2
#     Uninstalling openai-1.14.2:
#       Successfully uninstalled openai-1.14.2
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.1.33
#     Uninstalling langchain-core-0.1.33:
#       Successfully uninstalled langchain-core-0.1.33
#   Attempting uninstall: langchain-community
#     Found existing installation: langchain-community 0.0.28
#     Uninstalling langchain-community-0.0.28:
#       Successfully uninstalled langchain-community-0.0.28
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.1.12
#     Uninstalling langchain-0.1.12:
#       Successfully uninstalled langchain-0.1.12
#   Attempting uninstall: langchain-experimental
#     Found existing installation: langchain-experimental 0.0.54
#     Uninstalling langchain-experimental-0.0.54:
#       Successfully uninstalled langchain-experimental-0.0.54
# Successfully installed langchain-0.1.16 langchain-community-0.0.32 langchain-core-0.1.42 langchain-experimental-0.0.57 openai-1.17.1

# %%
! pip install "unstructured[all-docs]" pillow pydantic lxml pillow matplotlib chromadb tiktoken
# Out:
# Requirement already satisfied: pillow in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (10.2.0)
# Requirement already satisfied: pydantic in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (2.6.3)
# Requirement already satisfied: lxml in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (4.9.4)
# Requirement already satisfied: matplotlib in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (3.8.3)
# Requirement already satisfied: chromadb in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (0.4.24)
# Requirement already satisfied: tiktoken in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (0.6.0)
# Requirement already satisfied: unstructured[all-docs] in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (0.12.5)
# Requirement already satisfied: chardet in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (5.2.0)
# Requirement already satisfied: filetype in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (1.2.0)
# Requirement already satisfied: python-magic in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (0.4.27)
# Requirement already satisfied: nltk in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (3.8.1)
# Requirement already satisfied: tabulate in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (0.9.0)
# Requirement already satisfied: requests in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (4.12.3)
# Requirement already satisfied: emoji in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (2.10.1)
# Requirement already satisfied: dataclasses-json in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (0.6.4)
# Requirement already satisfied: python-iso639 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (2024.2.7)
# Requirement already satisfied: langdetect in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (1.0.9)
# Requirement already satisfied: numpy in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (1.26.4)
# Requirement already satisfied: rapidfuzz in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (3.6.2)
# Requirement already satisfied: backoff in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (2.2.1)
# Requirement already satisfied: typing-extensions in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (4.10.0)
# Requirement already satisfied: unstructured-client>=0.15.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (0.21.1)
# Requirement already satisfied: wrapt in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (1.16.0)
# Requirement already satisfied: python-docx in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (1.1.0)
# Requirement already satisfied: pypdf in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (4.1.0)
# Requirement already satisfied: xlrd in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (2.0.1)
# Requirement already satisfied: pypandoc in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (1.13)
# Requirement already satisfied: pillow-heif in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (0.15.0)
# Requirement already satisfied: python-pptx<=0.6.23 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (0.6.23)
# Requirement already satisfied: openpyxl in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (3.1.2)
# Requirement already satisfied: pikepdf in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (8.13.0)
# Requirement already satisfied: onnx in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (1.15.0)
# Requirement already satisfied: pdf2image in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (1.17.0)
# Requirement already satisfied: unstructured-inference==0.7.23 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (0.7.23)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (0.3.12)
# Requirement already satisfied: pandas in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (2.2.0)
# Requirement already satisfied: markdown in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (3.5.2)
# Requirement already satisfied: msg-parser in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (1.2.0)
# Requirement already satisfied: networkx in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (3.2.1)
# Requirement already satisfied: pdfminer.six in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured[all-docs]) (20221105)
# Requirement already satisfied: layoutparser[layoutmodels,tesseract] in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured-inference==0.7.23->unstructured[all-docs]) (0.3.4)
# Requirement already satisfied: python-multipart in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured-inference==0.7.23->unstructured[all-docs]) (0.0.7)
# Requirement already satisfied: huggingface-hub in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured-inference==0.7.23->unstructured[all-docs]) (0.20.3)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured-inference==0.7.23->unstructured[all-docs]) (4.9.0.80)
# Requirement already satisfied: onnxruntime<1.16 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured-inference==0.7.23->unstructured[all-docs]) (1.15.1)
# Requirement already satisfied: transformers>=4.25.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured-inference==0.7.23->unstructured[all-docs]) (4.38.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from pydantic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from pydantic) (2.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (0.109.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.27.1)
# Requirement already satisfied: posthog>=2.4.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (3.4.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (1.23.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (1.23.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (0.44b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (1.23.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (0.15.2)
# Requirement already satisfied: pypika>=0.48.9 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (4.66.1)
# Requirement already satisfied: overrides>=7.3.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (6.1.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (1.62.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (4.0.1)
# Requirement already satisfied: typer>=0.9.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (29.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from chromadb) (3.9.15)
# Requirement already satisfied: regex>=2022.1.18 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from tiktoken) (2023.12.25)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from fastapi>=0.95.2->chromadb) (0.36.3)
# Requirement already satisfied: certifi>=14.05.14 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2023.11.17)
# Requirement already satisfied: six>=1.9.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.28.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.26.18)
# Requirement already satisfied: coloredlogs in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from onnxruntime<1.16->unstructured-inference==0.7.23->unstructured[all-docs]) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from onnxruntime<1.16->unstructured-inference==0.7.23->unstructured[all-docs]) (23.5.26)
# Requirement already satisfied: protobuf in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from onnxruntime<1.16->unstructured-inference==0.7.23->unstructured[all-docs]) (4.24.4)
# Requirement already satisfied: sympy in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from onnxruntime<1.16->unstructured-inference==0.7.23->unstructured[all-docs]) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<7.0,>=6.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (6.10.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.62.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.23.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.23.0)
# Requirement already satisfied: opentelemetry-proto==1.23.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.23.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.44b0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.44b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.44b0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.44b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.44b0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.44b0)
# Requirement already satisfied: opentelemetry-util-http==0.44b0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.44b0)
# Requirement already satisfied: setuptools>=16.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (68.2.2)
# Requirement already satisfied: asgiref~=3.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from opentelemetry-instrumentation-asgi==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.7.2)
# Requirement already satisfied: monotonic>=1.5 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (1.5)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from python-pptx<=0.6.23->unstructured[all-docs]) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from requests->unstructured[all-docs]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from requests->unstructured[all-docs]) (3.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: deepdiff>=6.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured[all-docs]) (6.7.1)
# Requirement already satisfied: jsonpath-python>=1.0.6 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured[all-docs]) (1.0.6)
# Requirement already satisfied: marshmallow>=3.19.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured[all-docs]) (3.21.1)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured[all-docs]) (1.0.0)
# Requirement already satisfied: typing-inspect>=0.9.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured[all-docs]) (0.9.0)
# Requirement already satisfied: h11>=0.8 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (10.4)
# Requirement already satisfied: soupsieve>1.2 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from beautifulsoup4->unstructured[all-docs]) (2.5)
# Requirement already satisfied: olefile>=0.46 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from msg-parser->unstructured[all-docs]) (0.47)
# Requirement already satisfied: joblib in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from nltk->unstructured[all-docs]) (1.3.2)
# Requirement already satisfied: et-xmlfile in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from openpyxl->unstructured[all-docs]) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from pandas->unstructured[all-docs]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from pandas->unstructured[all-docs]) (2024.1)
# Requirement already satisfied: cryptography>=36.0.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from pdfminer.six->unstructured[all-docs]) (42.0.5)
# Requirement already satisfied: cffi>=1.12 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]) (1.16.0)
# Requirement already satisfied: ordered-set<4.2.0,>=4.0.2 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from deepdiff>=6.0->unstructured-client>=0.15.1->unstructured[all-docs]) (4.1.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from huggingface-hub->unstructured-inference==0.7.23->unstructured[all-docs]) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from huggingface-hub->unstructured-inference==0.7.23->unstructured[all-docs]) (2024.2.0)
# Requirement already satisfied: zipp>=0.5 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from importlib-metadata<7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from starlette<0.37.0,>=0.36.3->fastapi>=0.95.2->chromadb) (4.3.0)
# Requirement already satisfied: safetensors>=0.4.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from transformers>=4.25.1->unstructured-inference==0.7.23->unstructured[all-docs]) (0.4.2)
# Requirement already satisfied: humanfriendly>=9.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from coloredlogs->onnxruntime<1.16->unstructured-inference==0.7.23->unstructured[all-docs]) (10.0)
# Requirement already satisfied: scipy in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[all-docs]) (1.12.0)
# Requirement already satisfied: iopath in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[all-docs]) (0.1.10)
# Requirement already satisfied: pdfplumber in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[all-docs]) (0.10.4)
# Requirement already satisfied: torch in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[all-docs]) (2.2.1)
# Requirement already satisfied: torchvision in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[all-docs]) (0.17.1)
# Requirement already satisfied: effdet in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[all-docs]) (0.4.1)
# Requirement already satisfied: pytesseract in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[all-docs]) (0.3.10)
# Requirement already satisfied: mpmath>=0.19 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from sympy->onnxruntime<1.16->unstructured-inference==0.7.23->unstructured[all-docs]) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.37.0,>=0.36.3->fastapi>=0.95.2->chromadb) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.37.0,>=0.36.3->fastapi>=0.95.2->chromadb) (1.2.0)
# Requirement already satisfied: pycparser in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]) (2.21)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.5.1)
# Requirement already satisfied: timm>=0.9.2 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[all-docs]) (0.9.16)
# Requirement already satisfied: pycocotools>=2.0.2 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[all-docs]) (2.0.7)
# Requirement already satisfied: omegaconf>=2.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[all-docs]) (2.3.0)
# Requirement already satisfied: jinja2 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[all-docs]) (3.1.3)
# Requirement already satisfied: portalocker in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from iopath->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[all-docs]) (2.8.2)
# Requirement already satisfied: pypdfium2>=4.18.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[all-docs]) (4.27.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from omegaconf>=2.0->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[all-docs]) (4.9.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/cyrilvarghese/miniforge3/lib/python3.10/site-packages (from jinja2->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[all-docs]) (2.1.5)

# %%
from langchain_text_splitters import CharacterTextSplitter
from unstructured.partition.pdf import partition_pdf


# Extract elements from PDF
def extract_pdf_elements(path, fname):
    """
    Extract images, tables, and chunk text from a PDF file.
    path: File path, which is used to dump images (.jpg)
    fname: File name
    """
    return partition_pdf(
        filename=path + fname,
        extract_images_in_pdf=False,
        infer_table_structure=True,
        chunking_strategy="by_title",
        max_characters=4000,
        new_after_n_chars=3800,
        combine_text_under_n_chars=2000,
        image_output_dir_path=path,
    )


# Categorize elements by type
def categorize_elements(raw_pdf_elements):
    """
    Categorize extracted elements from a PDF into tables and texts.
    raw_pdf_elements: List of unstructured.documents.elements
    """
    tables = []
    texts = []
    for element in raw_pdf_elements:
        if "unstructured.documents.elements.Table" in str(type(element)):
            tables.append(str(element))
        elif "unstructured.documents.elements.CompositeElement" in str(type(element)):
            texts.append(str(element))
    return texts, tables


# File path
fpath = "../server/uploads/"
fname = "educational-perf.pdf"

# Get elements
raw_pdf_elements = extract_pdf_elements(fpath, fname)

# Get text, tables
texts, tables = categorize_elements(raw_pdf_elements)

# Optional: Enforce a specific token size for texts
text_splitter = CharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=4000, chunk_overlap=0
)
joined_texts = " ".join(texts)
texts_4k_token = text_splitter.split_text(joined_texts)
# Out:
# This function will be deprecated in a future release and `unstructured` will simply use the DEFAULT_MODEL from `unstructured_inference.model.base` to set default model name

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()
# Generate summaries of text elements
def generate_text_summaries(texts, tables, summarize_texts=False):
    """
    Summarize text elements
    texts: List of str
    tables: List of str
    summarize_texts: Bool to summarize texts
    """

    # Prompt
    prompt_text = """You are an assistant tasked with summarizing tables and text for retrieval. \
    These summaries will be embedded and used to retrieve the raw text or table elements. \
    Give a concise summary of the table or text that is well optimized for retrieval. Table or text: {element} """
    prompt = ChatPromptTemplate.from_template(prompt_text)

    # Text summary chain
    model = ChatOpenAI(temperature=0, model="gpt-3.5-turbo-0125")
    summarize_chain = {"element": lambda x: x} | prompt | model | StrOutputParser()

    # Initialize empty summaries
    text_summaries = []
    table_summaries = []

    # Apply to text if texts are provided and summarization is requested
    if texts and summarize_texts:
        text_summaries = summarize_chain.batch(texts, {"max_concurrency": 5})
    elif texts:
        text_summaries = texts

    # Apply to tables if tables are provided
    if tables:
        table_summaries = summarize_chain.batch(tables, {"max_concurrency": 5})

    return text_summaries, table_summaries


# Get text, table summaries
text_summaries, table_summaries = generate_text_summaries(
    texts_4k_token, tables, summarize_texts=True
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[14], line 43
#      39     return text_summaries, table_summaries
#      42 # Get text, table summaries
# ---> 43 text_summaries, table_summaries = generate_text_summaries(
#      44     texts_4k_token, tables, summarize_texts=True
#      45 )
#
# Cell In[14], line 37, in generate_text_summaries(texts, tables, summarize_texts)
#      35 # Apply to tables if tables are provided
#      36 if tables:
# ---> 37     table_summaries = summarize_chain.batch(tables, {"max_concurrency": 5})
#      39 return text_summaries, table_summaries
#
# File ~/miniforge3/lib/python3.10/site-packages/langchain_core/runnables/base.py:2643, in RunnableSequence.batch(self, inputs, config, return_exceptions, **kwargs)
#    2641     else:
#    2642         for i, step in enumerate(self.steps):
# -> 2643             inputs = step.batch(
#    2644                 inputs,
#    2645                 [
#    2646                     # each step a child run of the corresponding root run
#    2647                     patch_config(
#    2648                         config, callbacks=rm.get_child(f"seq:step:{i+1}")
#    2649                     )
#    2650                     for rm, config in zip(run_managers, configs)
#    2651                 ],
#    2652             )
#    2654 # finish the root runs
#    2655 except BaseException as e:
#
# File ~/miniforge3/lib/python3.10/site-packages/langchain_core/runnables/base.py:634, in Runnable.batch(self, inputs, config, return_exceptions, **kwargs)
#     631     return cast(List[Output], [invoke(inputs[0], configs[0])])
#     633 with get_executor_for_config(configs[0]) as executor:
# --> 634     return cast(List[Output], list(executor.map(invoke, inputs, configs)))
#
# File ~/miniforge3/lib/python3.10/concurrent/futures/_base.py:621, in Executor.map.<locals>.result_iterator()
#     618 while fs:
#     619     # Careful not to keep a reference to the popped future
#     620     if timeout is None:
# --> 621         yield _result_or_cancel(fs.pop())
#     622     else:
#     623         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/miniforge3/lib/python3.10/concurrent/futures/_base.py:319, in _result_or_cancel(***failed resolving arguments***)
#     317 try:
#     318     try:
# --> 319         return fut.result(timeout)
#     320     finally:
#     321         fut.cancel()
#
# File ~/miniforge3/lib/python3.10/concurrent/futures/_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File ~/miniforge3/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/miniforge3/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/miniforge3/lib/python3.10/site-packages/langchain_core/runnables/config.py:466, in ContextThreadPoolExecutor.map.<locals>._wrapped_fn(*args)
#     465 def _wrapped_fn(*args: Any) -> T:
# --> 466     return contexts.pop().run(fn, *args)
#
# File ~/miniforge3/lib/python3.10/site-packages/langchain_core/runnables/base.py:627, in Runnable.batch.<locals>.invoke(input, config)
#     625         return e
#     626 else:
# --> 627     return self.invoke(input, config, **kwargs)
#
# File ~/miniforge3/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:154, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     143 def invoke(
#     144     self,
#     145     input: LanguageModelInput,
#    (...)
#     149     **kwargs: Any,
#     150 ) -> BaseMessage:
#     151     config = ensure_config(config)
#     152     return cast(
#     153         ChatGeneration,
# --> 154         self.generate_prompt(
#     155             [self._convert_input(input)],
#     156             stop=stop,
#     157             callbacks=config.get("callbacks"),
#     158             tags=config.get("tags"),
#     159             metadata=config.get("metadata"),
#     160             run_name=config.get("run_name"),
#     161             run_id=config.pop("run_id", None),
#     162             **kwargs,
#     163         ).generations[0][0],
#     164     ).message
#
# File ~/miniforge3/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:556, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     548 def generate_prompt(
#     549     self,
#     550     prompts: List[PromptValue],
#    (...)
#     553     **kwargs: Any,
#     554 ) -> LLMResult:
#     555     prompt_messages = [p.to_messages() for p in prompts]
# --> 556     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/miniforge3/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:417, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     415         if run_managers:
#     416             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 417         raise e
#     418 flattened_outputs = [
#     419     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     420     for res in results
#     421 ]
#     422 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/miniforge3/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:407, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     404 for i, m in enumerate(messages):
#     405     try:
#     406         results.append(
# --> 407             self._generate_with_cache(
#     408                 m,
#     409                 stop=stop,
#     410                 run_manager=run_managers[i] if run_managers else None,
#     411                 **kwargs,
#     412             )
#     413         )
#     414     except BaseException as e:
#     415         if run_managers:
#
# File ~/miniforge3/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:626, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     624 else:
#     625     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 626         result = self._generate(
#     627             messages, stop=stop, run_manager=run_manager, **kwargs
#     628         )
#     629     else:
#     630         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/miniforge3/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:438, in ChatOpenAI._generate(self, messages, stop, run_manager, stream, **kwargs)
#     432 message_dicts, params = self._create_message_dicts(messages, stop)
#     433 params = {
#     434     **params,
#     435     **({"stream": stream} if stream is not None else {}),
#     436     **kwargs,
#     437 }
# --> 438 response = self.client.create(messages=message_dicts, **params)
#     439 return self._create_chat_result(response)
#
# File ~/miniforge3/lib/python3.10/site-packages/openai/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.10/site-packages/openai/resources/chat/completions.py:667, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     615 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     616 def create(
#     617     self,
#    (...)
#     665     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     666 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 667     return self._post(
#     668         "/chat/completions",
#     669         body=maybe_transform(
#     670             {
#     671                 "messages": messages,
#     672                 "model": model,
#     673                 "frequency_penalty": frequency_penalty,
#     674                 "function_call": function_call,
#     675                 "functions": functions,
#     676                 "logit_bias": logit_bias,
#     677                 "logprobs": logprobs,
#     678                 "max_tokens": max_tokens,
#     679                 "n": n,
#     680                 "presence_penalty": presence_penalty,
#     681                 "response_format": response_format,
#     682                 "seed": seed,
#     683                 "stop": stop,
#     684                 "stream": stream,
#     685                 "temperature": temperature,
#     686                 "tool_choice": tool_choice,
#     687                 "tools": tools,
#     688                 "top_logprobs": top_logprobs,
#     689                 "top_p": top_p,
#     690                 "user": user,
#     691             },
#     692             completion_create_params.CompletionCreateParams,
#     693         ),
#     694         options=make_request_options(
#     695             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     696         ),
#     697         cast_to=ChatCompletion,
#     698         stream=stream or False,
#     699         stream_cls=Stream[ChatCompletionChunk],
#     700     )
#
# File ~/miniforge3/lib/python3.10/site-packages/openai/_base_client.py:1233, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1219 def post(
#    1220     self,
#    1221     path: str,
#    (...)
#    1228     stream_cls: type[_StreamT] | None = None,
#    1229 ) -> ResponseT | _StreamT:
#    1230     opts = FinalRequestOptions.construct(
#    1231         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1232     )
# -> 1233     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniforge3/lib/python3.10/site-packages/openai/_base_client.py:922, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     913 def request(
#     914     self,
#     915     cast_to: Type[ResponseT],
#    (...)
#     920     stream_cls: type[_StreamT] | None = None,
#     921 ) -> ResponseT | _StreamT:
# --> 922     return self._request(
#     923         cast_to=cast_to,
#     924         options=options,
#     925         stream=stream,
#     926         stream_cls=stream_cls,
#     927         remaining_retries=remaining_retries,
#     928     )
#
# File ~/miniforge3/lib/python3.10/site-packages/openai/_base_client.py:998, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     996 if retries > 0 and self._should_retry(err.response):
#     997     err.response.close()
# --> 998     return self._retry_request(
#     999         options,
#    1000         cast_to,
#    1001         retries,
#    1002         err.response.headers,
#    1003         stream=stream,
#    1004         stream_cls=stream_cls,
#    1005     )
#    1007 # If the response is streamed then we need to explicitly read the response
#    1008 # to completion before attempting to access the response text.
#    1009 if not err.response.is_closed:
#
# File ~/miniforge3/lib/python3.10/site-packages/openai/_base_client.py:1046, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1042 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1043 # different thread if necessary.
#    1044 time.sleep(timeout)
# -> 1046 return self._request(
#    1047     options=options,
#    1048     cast_to=cast_to,
#    1049     remaining_retries=remaining,
#    1050     stream=stream,
#    1051     stream_cls=stream_cls,
#    1052 )
#
# File ~/miniforge3/lib/python3.10/site-packages/openai/_base_client.py:998, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     996 if retries > 0 and self._should_retry(err.response):
#     997     err.response.close()
# --> 998     return self._retry_request(
#     999         options,
#    1000         cast_to,
#    1001         retries,
#    1002         err.response.headers,
#    1003         stream=stream,
#    1004         stream_cls=stream_cls,
#    1005     )
#    1007 # If the response is streamed then we need to explicitly read the response
#    1008 # to completion before attempting to access the response text.
#    1009 if not err.response.is_closed:
#
# File ~/miniforge3/lib/python3.10/site-packages/openai/_base_client.py:1046, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1042 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1043 # different thread if necessary.
#    1044 time.sleep(timeout)
# -> 1046 return self._request(
#    1047     options=options,
#    1048     cast_to=cast_to,
#    1049     remaining_retries=remaining,
#    1050     stream=stream,
#    1051     stream_cls=stream_cls,
#    1052 )
#
# File ~/miniforge3/lib/python3.10/site-packages/openai/_base_client.py:1013, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1010         err.response.read()
#    1012     log.debug("Re-raising status error")
# -> 1013     raise self._make_status_error_from_response(err.response) from None
#    1015 return self._process_response(
#    1016     cast_to=cast_to,
#    1017     options=options,
#    (...)
#    1020     stream_cls=stream_cls,
#    1021 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo-0125 in organization org-bgcMwbxlEB8J58EodaAQr2sV on requests per min (RPM): Limit 3, Used 3, Requested 1. Please try again in 20s. Visit https://platform.openai.com/account/rate-limits to learn more. You can increase your rate limit by adding a payment method to your account at https://platform.openai.com/account/billing.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}
